# %% [markdown]
# <a href="https://colab.research.google.com/github/JeonJongDae/dinner_stock_AI/blob/main/2%EC%A3%BC%EC%B0%A8/pandas_exercise.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

np.random.seed(0)

# %% [markdown]
# # 과제 1
# ## Q1.
#
#
# <div class="alert alert-success">
# [문제1]
#
# insurance.csv'파일 읽어서 df에 할당하고, 상위 5개 항목 출력하기
# </div>
#
# ------------
#
# [힌트]
#
# pd.read_csv()

# %%
df = pd.read_csv('https://raw.githubusercontent.com/zzhining/ml_basic/main/dataset/insurance.csv')

# %%
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %% [markdown]
# ## Q2.
#
#
# <div class="alert alert-success">
# [문제2]
#
# df의 요약(평균, 4분위수, 전체 갯수 등)정보 확인하기
# </div>
#
# ------------

# %%
# 주요 통계지표
df.describe()
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %% [markdown]
# ## Q3.
#
#
# <div class="alert alert-success">
# [문제3]
#
# 신규 컬럼(double bmi)을 생성하고, bmi의 2배가 되는 값을 할당하기
# </div>
#
# ------------

# %%
df['double bmi'] = df['bmi'] * 2

# %%
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges  double bmi
# 0   19  female  27.900         0    yes  southwest  16884.92400       55.80
# 1   18    male  33.770         1     no  southeast   1725.55230       67.54
# 2   28    male  33.000         3     no  southeast   4449.46200       66.00
# 3   33    male  22.705         0     no  northwest  21984.47061       45.41
# 4   32    male  28.880         0     no  northwest   3866.85520       57.76

# %% [markdown]
# ## Q4.
#
#
# <div class="alert alert-success">
# [문제4]
#
# 신규 컬럼(debt)을 생성하고, 0으로 채우기
# </div>
#
# ------------

# %%
df['debt'] = 0
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges  double bmi  \
# 0   19  female  27.900         0    yes  southwest  16884.92400       55.80
# 1   18    male  33.770         1     no  southeast   1725.55230       67.54
# 2   28    male  33.000         3     no  southeast   4449.46200       66.00
# 3   33    male  22.705         0     no  northwest  21984.47061       45.41
# 4   32    male  28.880         0     no  northwest   3866.85520       57.76
#
#    debt
# 0     0
# 1     0
# 2     0
# 3     0
# 4     0

# %% [markdown]
# ## Q5.
#
#
# <div class="alert alert-success">
# [문제5]
#
# debt에 0부터 값이 증가하도록 채우기
# </div>
#
# ------------

# %%
df['debt'] = np.arange(len(df))
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges  double bmi  \
# 0   19  female  27.900         0    yes  southwest  16884.92400       55.80
# 1   18    male  33.770         1     no  southeast   1725.55230       67.54
# 2   28    male  33.000         3     no  southeast   4449.46200       66.00
# 3   33    male  22.705         0     no  northwest  21984.47061       45.41
# 4   32    male  28.880         0     no  northwest   3866.85520       57.76
#
#    debt
# 0     0
# 1     1
# 2     2
# 3     3
# 4     4

# %% [markdown]
# ## Q6.
#
#
# <div class="alert alert-success">
# [문제6]
#
# 1번 인덱스의 정보 출력
# </div>
#
# ------------
#
# [힌트]
# iloc
#
#
#
# age                  18
# sex                male
# bmi               33.77
# children              1
# smoker               no
# region        southeast
# charges         1725.55
# double bmi        67.54
# debt                  1

# %%
df.iloc[1]
# Out:
# age                  18
# sex                male
# bmi               33.77
# children              1
# smoker               no
# region        southeast
# charges       1725.5523
# double bmi        67.54
# debt                  1
# Name: 1, dtype: object

# %% [markdown]
# ## Q7.
#
#
# <div class="alert alert-success">
# [문제7]
#
# 'double bmi'열 삭제하기
# </div>

# %%
# axis = 1: 축을 컬럼방향으로 설정하기 위한 매개변수
# inplace = True: df 객체에 있는 값을 연산 결과로 대체
df.drop(['double bmi'], axis=1, inplace = True)

# %%
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges  debt
# 0   19  female  27.900         0    yes  southwest  16884.92400     0
# 1   18    male  33.770         1     no  southeast   1725.55230     1
# 2   28    male  33.000         3     no  southeast   4449.46200     2
# 3   33    male  22.705         0     no  northwest  21984.47061     3
# 4   32    male  28.880         0     no  northwest   3866.85520     4

# %% [markdown]
# ## Q8.
#
#
# <div class="alert alert-success">
# [문제8]
#
#  'age'열, 'sex'열만 출력하기
# </div>

# %%
df[['age', 'sex']]
# Out:
#       age     sex
# 0      19  female
# 1      18    male
# 2      28    male
# 3      33    male
# 4      32    male
# ...   ...     ...
# 1333   50    male
# 1334   18  female
# 1335   18  female
# 1336   21  female
# 1337   61  female
#
# [1338 rows x 2 columns]

# %% [markdown]
# # 과제2
# ## Q9.
# <div class="alert alert-success">
# [문제9]
#
# 나이를 1살씩 증가시키기
# </div>

# %%
df['age'] = df['age'] + 1

# %%
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges  debt
# 0   20  female  27.900         0    yes  southwest  16884.92400     0
# 1   19    male  33.770         1     no  southeast   1725.55230     1
# 2   29    male  33.000         3     no  southeast   4449.46200     2
# 3   34    male  22.705         0     no  northwest  21984.47061     3
# 4   33    male  28.880         0     no  northwest   3866.85520     4

# %% [markdown]
# ## Q10.
# <div class="alert alert-success">
# [문제10]
#
# charges의 표시형식을 소수점 아래 2자리로 바꾸기
# </div>
#
# [힌트]
#
# 함수 생성, 적용(apply/map)

# %%
# round(): 반올림
df['charges'].round(2)
# Out:
# 0       16884.92
# 1        1725.55
# 2        4449.46
# 3       21984.47
# 4        3866.86
#           ...
# 1333    10600.55
# 1334     2205.98
# 1335     1629.83
# 1336     2007.94
# 1337    29141.36
# Name: charges, Length: 1338, dtype: float64

# %%
test_num = 123.45678

def sosu(data):
    return format(data, ".2f")

sosu(5883829.2326)
# Out:
# '5883829.23'

# %%
df['charges'] = df['charges'].apply(sosu)

# %%
df.head()
# Out:
#    age     sex     bmi  children smoker     region   charges  debt
# 0   20  female  27.900         0    yes  southwest  16884.92     0
# 1   19    male  33.770         1     no  southeast   1725.55     1
# 2   29    male  33.000         3     no  southeast   4449.46     2
# 3   34    male  22.705         0     no  northwest  21984.47     3
# 4   33    male  28.880         0     no  northwest   3866.86     4

# %% [markdown]
# ## Q11.
# <div class="alert alert-success">
# [문제11]
#
# 컬럼 정렬(알파벳 순서대로) : age, bmi, charges... 순으로 정렬
# </div>
#
# [Hint]
# sort_index()

# %%
df.sort_index(axis = 1, inplace=True)

# %%
df.head()
# Out:
#    age     bmi   charges  children  debt     region     sex smoker
# 0   20  27.900  16884.92         0     0  southwest  female    yes
# 1   19  33.770   1725.55         1     1  southeast    male     no
# 2   29  33.000   4449.46         3     2  southeast    male     no
# 3   34  22.705  21984.47         0     3  northwest    male     no
# 4   33  28.880   3866.86         0     4  northwest    male     no

# %% [markdown]
# ## Q12.
# <div class="alert alert-success">
# [문제12]
#
# 값 정렬(age) : 나이 순으로 정렬
# </div>
#
# [Hint]
# sort_values

# %%
df.sort_values(by ='age')
# Out:
#       age     bmi   charges  children  debt     region     sex smoker
# 1248   19  39.820   1633.96         0  1248  southeast  female     no
# 482    19  31.350   1622.19         0   482  southeast  female     no
# 492    19  25.080   2196.47         0   492  northeast  female     no
# 525    19  33.880  11482.63         0   525  southeast  female     no
# 529    19  25.460   1708.00         0   529  northeast    male     no
# ...   ...     ...       ...       ...   ...        ...     ...    ...
# 398    65  25.600  14988.43         2   398  southwest    male     no
# 335    65  34.500  13822.80         0   335  southwest    male     no
# 378    65  30.115  16455.71         3   378  northwest  female     no
# 1265   65  23.760  26926.51         0  1265  southeast    male    yes
# 635    65  38.190  14410.93         0   635  northeast    male     no
#
# [1338 rows x 8 columns]

# %% [markdown]
# ## Q13.
# <div class="alert alert-success">
# [문제13]
#
# 나이('age') 평균구하기
# </div>
#
# [Hint]
# mean

# %%
df['age'].mean()
# Out:
# 40.20702541106129

# %% [markdown]
# ## Q14.
# <div class="alert alert-success">
# [문제14]
#
# 보험료('charges')와 가장 상관관계가 높은 변수는?
# </div>
#
# [Hint]
#  - 공분산: df.cov()
#  - 상관계수: df.corr()

# %%
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %% [markdown]
# # 과제 3
# ## Q15.
# <div class="alert alert-success">
# [문제15]
#
#  남자, 여자가 각각 몇명있는지 구하기
# </div>
#
# [Hint]
# pd.value_counts

# %%
df.value_counts('sex')
# Out:
# sex
# male      676
# female    662
# dtype: int64

# %% [markdown]
# ## Q16.
# <div class="alert alert-success">
# [문제16]
#
# 자녀(children)가 3명인 데이터 출력하기
# </div>

# %%
df3 = df['children']==3

# %%
df[df3]
# Out:
#       age     sex     bmi  children smoker     region      charges  childern
# 2      28    male  33.000         3     no  southeast   4449.46200         3
# 7      37  female  27.740         3     no  northwest   7281.50560         3
# 25     59  female  27.720         3     no  southeast  14001.13380         3
# 36     62  female  32.965         3     no  northwest  15612.19335         3
# 54     40  female  28.690         3     no  northwest   8059.67910         3
# ...   ...     ...     ...       ...    ...        ...          ...       ...
# 1301   62    male  30.875         3    yes  northwest  46718.16325         3
# 1314   30  female  23.655         3    yes  northwest  18765.87545         3
# 1320   31    male  31.065         3     no  northwest   5425.02335         3
# 1332   52  female  44.700         3     no  southwest  11411.68500         3
# 1333   50    male  30.970         3     no  northwest  10600.54830         3
#
# [157 rows x 8 columns]

# %% [markdown]
# ## Q16.
# <div class="alert alert-success">
# [문제16]
#
# 자녀(children)가  5명 이상인 데이터 출력하기
# </div>

# %%
df5=df['children']>=5

# %%
df[df5]
# Out:
#       age     sex     bmi  children smoker     region      charges  childern
# 32     19  female  28.600         5     no  southwest   4687.79700         3
# 71     31    male  28.500         5     no  northeast   6799.45800         3
# 166    20  female  37.000         5     no  southwest   4830.63000         3
# 413    25    male  23.900         5     no  southwest   5080.09600         3
# 425    45    male  24.310         5     no  southeast   9788.86590         3
# 438    52  female  46.750         5     no  southeast  12592.53450         3
# 568    49  female  31.900         5     no  southwest  11552.90400         3
# 640    33    male  42.400         5     no  southwest   6666.24300         3
# 877    33    male  33.440         5     no  southeast   6653.78860         3
# 932    46    male  25.800         5     no  southwest  10096.97000         3
# 937    39  female  24.225         5     no  northwest   8965.79575         3
# 969    39  female  34.320         5     no  southeast   8596.82780         3
# 984    20    male  30.115         5     no  northeast   4915.05985         3
# 1085   39  female  18.300         5    yes  southwest  19023.26000         3
# 1116   41    male  29.640         5     no  northeast   9222.40260         3
# 1130   39  female  23.870         5     no  southeast   8582.30230         3
# 1245   28    male  24.300         5     no  southwest   5615.36900         3
# 1272   43    male  25.520         5     no  southeast  14478.33015         3

# %% [markdown]
# ## Q17.
# <div class="alert alert-success">
# [문제17]
#
#  bmi가  17 미만인 데이터 출력하기
# </div>

# %%
bmi17 = df['bmi']<17

# %%
df[bmi17]
# Out:
#       age     sex     bmi  children smoker     region     charges  childern
# 172    18    male  15.960         0     no  northeast  1694.79640         3
# 428    21  female  16.815         1     no  northeast  3167.45585         3
# 1226   38    male  16.815         2     no  northeast  6640.54485         3

# %% [markdown]
# # 과제 4
# ## Q18.
# <div class="alert alert-success">
# [문제18]
#
# 성별에 따른 보험료 평균
# </div>

# %%
gby_sex =df.groupby('sex')

# %%
gby_sex['charges'].mean()
# Out:
# sex
# female    12569.578844
# male      13956.751178
# Name: charges, dtype: float64

# %% [markdown]
# ## Q19.
# <div class="alert alert-success">
# [문제19]
#
# 흡연여부에 따른 보험료 평균
# </div>

# %%
df.groupby('smoker')['charges'].mean()
# Out:
# smoker
# no      8434.268298
# yes    32050.231832
# Name: charges, dtype: float64

# %% [markdown]
# ## Q20.
# <div class="alert alert-success">
# [문제20]
#
# 지역별 보험료 평균
# </div>

# %%
df.groupby('region')['charges'].mean()
# Out:
# region
# northeast    13406.384516
# northwest    12417.575374
# southeast    14735.411438
# southwest    12346.937377
# Name: charges, dtype: float64

# %% [markdown]
# ## Q21.
# <div class="alert alert-success">
# [문제21]
#
# 흡연여부 + 지역별 데이터 평균
# </div>

# %%
df.groupby(['smoker','region'])['charges'].mean()
# Out:
# smoker  region
# no      northeast     9165.531672
#         northwest     8556.463715
#         southeast     8032.216309
#         southwest     8019.284513
# yes     northeast    29673.536473
#         northwest    30192.003182
#         southeast    34844.996824
#         southwest    32269.063494
# Name: charges, dtype: float64

# %% [markdown]
# ## Q22.
# <div class="alert alert-success">
# [문제22]
#
#  흡연여부 + 지역별 데이터 평균에서 'charges' 만 츨력하기
# </div>

# %%
df6=df.groupby(['smoker','region'])['charges'].mean()

# %%
print(df6[2])
# Out:
# 8032.216308937729

# %% [markdown]
# ## Q23.
# <div class="alert alert-success">
# [문제23]
#
#  흡연여부 + 지역별 데이터 크기(size)
# </div>

# %%
df7=df.groupby(['smoker','region']).count()

# %%
print(df7)
# Out:
#                   age  sex  bmi  children  charges  childern
# smoker region
# no     northeast  257  257  257       257      257       257
#        northwest  267  267  267       267      267       267
#        southeast  273  273  273       273      273       273
#        southwest  267  267  267       267      267       267
# yes    northeast   67   67   67        67       67        67
#        northwest   58   58   58        58       58        58
#        southeast   91   91   91        91       91        91
#        southwest   58   58   58        58       58        58

# %% [markdown]
# ## Q24.
# <div class="alert alert-success">
# [문제24]
#
# smoker 여부에 따라, group_val 컬럼에 '흡연자', '비흡연자' 표시하기
# </div>

# %%
df['group_val']=df['smoker'].replace(['yes','no'],['흡연자','비흡연자'])

# %%
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges  childern  \
# 0   19  female  27.900         0    yes  southwest  16884.92400         3
# 1   18    male  33.770         1     no  southeast   1725.55230         3
# 2   28    male  33.000         3     no  southeast   4449.46200         3
# 3   33    male  22.705         0     no  northwest  21984.47061         3
# 4   32    male  28.880         0     no  northwest   3866.85520         3
#
#   group_val
# 0       흡연자
# 1      비흡연자
# 2      비흡연자
# 3      비흡연자
# 4      비흡연자

# %%
df['group_val'] = df['group_val'].apply(lambda bool: 'smoker' if bool=='yes' else 'non-smoker')
df.head()

df['group_val'] = df['smoker'].apply(lambda bool: 'smoker' if bool=='yes' else 'non-smoker')
df.head(3)
# Out:
#    age     sex    bmi  children smoker     region     charges  childern  \
# 0   19  female  27.90         0    yes  southwest  16884.9240         3
# 1   18    male  33.77         1     no  southeast   1725.5523         3
# 2   28    male  33.00         3     no  southeast   4449.4620         3
#
#     group_val
# 0      smoker
# 1  non-smoker
# 2  non-smoker
