# %% [markdown]
# <a href="https://colab.research.google.com/github/JeonJongDae/dinner_stock_AI/blob/main/4%EC%A3%BC%EC%B0%A8/Homework_20230420.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from pandas_datareader import data
import yfinance as yfin
import pandas as pd
from datetime import timedelta
import plotly.graph_objects as go

yfin.pdr_override()

# %%
#주가 가져오기
def get_stocks(ticker, start_date,end_date):
    stock_df = data.get_data_yahoo(ticker, start = start_date, end=end_date)
    stock_df['Close'].plot()
    return stock_df

# %%
def run():#ticker, num, percent, start_price):
    ticker = input('시뮬레이션 할 종목의 티커를 입력하세요.(예:TSLA): ')
    start_date = input('가져올 시작일자를 입력하세요.(예:20200101): ')
    end_date = input('가져올 종료일자를 입력하세요.(예:20231231): ')
    stock_df = get_stocks(ticker,start_date,end_date)
    print(stock_df.tail())

# %%
run()
# Out:
# 시뮬레이션 할 종목의 티커를 입력하세요.(예:TSLA): U
# 가져올 시작일자를 입력하세요.(예:20200101): 2020-01-01
# 가져올 종료일자를 입력하세요.(예:20231231): 2023-04-20
# [*********************100%***********************]  1 of 1 completed
#                  Open       High        Low      Close  Adj Close   Volume
# Date
# 2023-04-13  29.139999  30.191000  29.120001  29.469999  29.469999  6169600
# 2023-04-14  29.400000  30.070000  28.840000  29.440001  29.440001  5840500
# 2023-04-17  29.230000  30.040001  28.879999  29.990000  29.990000  5015700
# 2023-04-18  30.559999  30.580000  29.231001  29.410000  29.410000  4826000
# 2023-04-19  28.930000  29.719999  28.839001  29.520000  29.520000  4004300

# %%
stock_df1.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-29-3419cb358d49> in <cell line: 1>()
# ----> 1 stock_df1.info()
#
# NameError: name 'stock_df1' is not defined
